# %%
# importing pandas
import pandas as pd

# %%
# list your files
fileslist=['your_16may.csv', 'your_17may.csv','your_18may.csv','your_19may.csv','your_20may.csv','your_21may.csv','your_22may.csv']

# %%
# merging csv files
df = pd.concat(map(pd.read_csv, fileslist), ignore_index=True)
print(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py:304: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   sort=sort,
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-989978985587> in <module>()
#       1 # merging csv files
# ----> 2 df = pd.concat(map(pd.read_csv, fileslist), ignore_index=True)
#       3 print(df)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
df.to_csv('16may-22may.csv')
